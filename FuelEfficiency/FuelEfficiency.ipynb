# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

import tensorflow as tf
from tensorflow import keras
from keras import layers

# %%
df = pd.read_csv('auto-mpg.csv')
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df['horsepower'].unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
print(df.shape)
df = df[df['horsepower'] != '?']
print(df.shape)
# Out:
# (398, 9)
# (392, 9)

# %%
df['horsepower'] = df['horsepower'].astype(int)
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
df.nunique()
# Out:
# mpg             127
# cylinders         5
# displacement     81
# horsepower       93
# weight          346
# acceleration     95
# model year       13
# origin            3
# car name        301
# dtype: int64

# %%
numeric_df = df.select_dtypes(include=['number'])
plt.figure(figsize=(8, 8))
sb.heatmap(numeric_df.corr() > 0.9,
           annot=True,
           cbar=False)
plt.show()

# %%
df.drop('displacement',
        axis=1,
        inplace=True)

# %%
from sklearn.model_selection import train_test_split
features = df.drop(['mpg', 'car name'], axis=1)
target = df['mpg'].values

X_train, X_val,Y_train, Y_val = train_test_split(features, target,
                                      test_size=0.2,
                                      random_state=22)
X_train.shape, X_val.shape
# Out:
# ((313, 6), (79, 6))

# %%
AUTO = tf.data.experimental.AUTOTUNE

train_ds = (
    tf.data.Dataset
    .from_tensor_slices((X_train, Y_train))
    .batch(32)
    .prefetch(AUTO)
)

val_ds = (
    tf.data.Dataset
    .from_tensor_slices((X_val, Y_val))
    .batch(32)
    .prefetch(AUTO)
)

# %%
model = keras.Sequential([
    layers.Dense(256, activation='relu', input_shape=[6]),
    layers.BatchNormalization(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(1, activation='relu')
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    loss='mae',
    optimizer='adam',
    metrics=['mape']
)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 256)                 │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │          65,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │             257 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 69,889 (273.00 KB)
#  Trainable params: 68,865 (269.00 KB)
#  Non-trainable params: 1,024 (4.00 KB)

# %%
history = model.fit(train_ds,
                    epochs=50,
                    validation_data=val_ds)
# Out:
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.7308 - mape: 18.9111 - val_loss: 21.3667 - val_mape: 92.3581
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.4813 - mape: 14.1481 - val_loss: 22.3205 - val_mape: 99.3442
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.0353 - mape: 13.0619 - val_loss: 22.4190 - val_mape: 100.0000
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.0744 - mape: 13.5484 - val_loss: 21.8099 - val_mape: 96.2570
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.8332 - mape: 13.1222 - val_loss: 17.6415 - val_mape: 72.8122
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.9310 - mape: 13.3199 - val_loss: 17.1576 - val_mape: 69.7278
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.8145 - mape: 12.8072 - val_loss: 14.6634 - val_mape: 56.8641
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.8229 - mape: 12.8825 - val_loss: 13.8676 - val_mape: 53.9324
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.7533 - mape: 12.4633 - val_loss: 11.4218 - val_mape: 42.5142
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.7655 - mape: 12.3504 - val_loss: 12.1959 - val_mape: 46.4459
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.7801 - mape: 12.2390 - val_loss: 7.9670 - val_mape: 31.3821
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.8021 - mape: 12.4672 - val_loss: 7.2079 - val_mape: 26.7259
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7584 - mape: 12.8716 - val_loss: 6.7209 - val_mape: 30.1300
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7734 - mape: 12.8149 - val_loss: 6.3704 - val_mape: 29.5636
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6968 - mape: 12.2101 - val_loss: 4.9840 - val_mape: 18.4690
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7898 - mape: 12.6123 - val_loss: 4.0085 - val_mape: 16.2899
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8333 - mape: 12.6363 - val_loss: 4.4320 - val_mape: 20.3357
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7605 - mape: 12.2806 - val_loss: 4.9713 - val_mape: 23.1224
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7046 - mape: 12.2292 - val_loss: 4.8952 - val_mape: 25.2124
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8144 - mape: 12.6584 - val_loss: 4.4198 - val_mape: 22.8131
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7588 - mape: 12.2938 - val_loss: 5.9160 - val_mape: 32.3592
# Epoch 22/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7611 - mape: 12.0933 - val_loss: 3.2132 - val_mape: 15.3390
# Epoch 23/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8545 - mape: 12.8192 - val_loss: 4.2526 - val_mape: 21.6703
# Epoch 24/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8132 - mape: 12.8817 - val_loss: 3.2784 - val_mape: 15.8496
# Epoch 25/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5812 - mape: 11.5965 - val_loss: 4.2170 - val_mape: 21.6605
# Epoch 26/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7643 - mape: 12.4348 - val_loss: 3.3801 - val_mape: 14.5575
# Epoch 27/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8696 - mape: 12.6466 - val_loss: 3.2435 - val_mape: 14.6314
# Epoch 28/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7200 - mape: 12.0935 - val_loss: 4.1794 - val_mape: 20.7594
# Epoch 29/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7548 - mape: 12.2315 - val_loss: 3.1102 - val_mape: 14.2006
# Epoch 30/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6751 - mape: 11.3563 - val_loss: 4.3410 - val_mape: 23.0922
# Epoch 31/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.7682 - mape: 12.4609 - val_loss: 4.3566 - val_mape: 22.4932
# Epoch 32/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8378 - mape: 12.3714 - val_loss: 4.4234 - val_mape: 22.3629
# Epoch 33/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8402 - mape: 12.9289 - val_loss: 6.6554 - val_mape: 35.6076
# Epoch 34/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6445 - mape: 12.1427 - val_loss: 4.0951 - val_mape: 20.0127
# Epoch 35/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.9893 - mape: 13.2142 - val_loss: 4.0031 - val_mape: 20.7839
# Epoch 36/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8237 - mape: 12.6518 - val_loss: 5.0426 - val_mape: 25.2680
# Epoch 37/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8509 - mape: 12.6815 - val_loss: 3.5373 - val_mape: 19.0284
# Epoch 38/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7952 - mape: 12.4766 - val_loss: 3.4621 - val_mape: 17.9762
# Epoch 39/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9023 - mape: 12.6101 - val_loss: 5.2012 - val_mape: 27.2038
# Epoch 40/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.9833 - mape: 13.4228 - val_loss: 3.7208 - val_mape: 18.5177
# Epoch 41/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8606 - mape: 12.8863 - val_loss: 2.2379 - val_mape: 9.2550
# Epoch 42/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7849 - mape: 12.4763 - val_loss: 2.5109 - val_mape: 11.6791
# Epoch 43/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7236 - mape: 12.2420 - val_loss: 2.3721 - val_mape: 10.6113
# Epoch 44/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.9332 - mape: 13.1272 - val_loss: 2.9126 - val_mape: 14.8508
# Epoch 45/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7301 - mape: 12.8452 - val_loss: 3.4511 - val_mape: 17.3718
# Epoch 46/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6055 - mape: 11.3996 - val_loss: 2.7713 - val_mape: 13.1518
# Epoch 47/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6633 - mape: 12.0539 - val_loss: 3.2121 - val_mape: 15.9700
# Epoch 48/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8717 - mape: 13.0310 - val_loss: 2.8298 - val_mape: 11.8628
# Epoch 49/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7547 - mape: 12.6299 - val_loss: 4.1103 - val_mape: 20.2026
# Epoch 50/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6658 - mape: 12.1365 - val_loss: 5.1147 - val_mape: 25.1805

# %%
history_df = pd.DataFrame(history.history)
history_df.head()
# Out:
#        loss       mape   val_loss    val_mape
# 0  4.542083  17.998653  21.366690   92.358116
# 1  3.449366  14.140981  22.320467   99.344162
# 2  3.073053  13.177454  22.418987  100.000000
# 3  3.099708  13.510580  21.809948   96.257050
# 4  2.951353  13.237629  17.641495   72.812180
